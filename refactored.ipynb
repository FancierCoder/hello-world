# %% [markdown]
# <a href="https://colab.research.google.com/github/FancierCoder/hello-world/blob/master/refactored.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyLDAvis
import jieba
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis.sklearn

def chinese_word_cut(mytext):
    return " ".join(jieba.cut(mytext))


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()
# Out:
# ...
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# /usr/local/lib/python3.7/dist-packages/past/builtins/misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping

# %%
file_name = 'zd_bz_csv.csv'
stopword = open('stopword', 'rb').read()

jieba.load_userdict('userdict')

df = pd.read_csv(file_name, encoding='utf-8')
df["content_cutted"] = df.BZ.apply(chinese_word_cut)

n_features = 1000

tf_vectorizer = CountVectorizer(strip_accents='unicode',
                                max_features=n_features,
                                stop_words=stopword,
                                max_df=0.5,
                                min_df=10)
tf = tf_vectorizer.fit_transform(df.content_cutted)

n_topics = 10
lda = LatentDirichletAllocation(n_components=n_topics, max_iter=50,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(tf)

n_top_words = 20
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)

pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.836 seconds.
# Prefix dict has been built successfully.
# Topic #0:
# 建设 项目 标准 地块 竞得 要求 规划 按照 住房 开发 安置 相关 配建 无偿 进行 根据 移交 关于 政府 配套
# Topic #1:
# 用地 要求 建筑 项目 面积 设施 不得 办公 工业 规定 服务设施 生活 超过 红线 行政 相关 满足 建设 规划 低于
# Topic #2:
# 竞得 出让 建设 土地 签订 合同 用地 之日起 使用权 成交 国有 价款 缴纳 竣工 土地出让 保证金 开工 支付 约定 项目
# Topic #3:
# 建筑面积 平方米 建筑 容积率 地块 大于 面积 小于 用地 m2 建筑密度 绿地率 地下 规划 30 商业 计容 20 高度 用房
# Topic #4:
# 条件 规划 地上 出让 详见 要求 规划设计 土地 建筑物 其他 地块 为准 建设 文件 万元 具体 执行 指标 出具 该宗地
# Topic #5:
# 万元 起始价 该宗地 工业用地 加价幅度 土地 10 出让 产业 幅度 投资强度 增价 用途 工业 人民币 整数倍 低于 税收 准入 50
# Topic #6:
# 出让 土地 地块 费用 本次 自行 挂牌 建设 承担 设施 受让人 竞得 使用权 耕地 契税 竞买 现状 成交 保留 占用
# Topic #7:
# 用地 商业 住宅 40 70 出让年限 用途 土地 兼容 城镇 该宗地 商服用地 居住用地 商住 年限 零售 使用 商服 居住 规划
# Topic #8:
# 平方米 面积 用地 地块 出让 土地 挂牌 其中 该宗地 分摊 交易 国土 服务费 规划 01 02 宗地 本次 实际 编号
# Topic #9:
# 竞买 保证金 出让 竞买人 时间 挂牌 公共资源 拍卖 网上 交易中心 土地 使用权 交纳 申请 文件 地块 公告 本次 方式 2019
# ...
